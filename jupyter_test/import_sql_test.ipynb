# %%
from connSql import mkcon
cursor, mconn = mkcon()
cursor.execute('use fortest')
# Out:
# Set level
# 'DEBUG' ----> Basic log level
#
# Set level
# 'DEBUG' ----> Log FileHandler
#
# SF:     Using ---> crLog(level = ('DEBUG','DEBUG','INFO'), fname = 'D:\\桌面\\Log-test.log', head = 'SF', ifile = True, cls = False)
#
#
# SF:     Building connection to Mysql...

# %%
cursor.execute('select hashid from fline_code where line regexp "conn" ')

# %%
rows = cursor.fetchall()
for r in rows:
    print(r)
# Out:
# (19,)
# (19,)
# (19,)
# (19,)
# (19,)
# (19,)
# (19,)
# (19,)
# (19,)
# (19,)
# (19,)
# (19,)
# (19,)
# (38,)
# (38,)
# (38,)
# (38,)
# (38,)
# (61,)
# (61,)
# (61,)
# (61,)
# (61,)
# (61,)
# (61,)
# (61,)
# (61,)
# (69,)
# (79,)
# (79,)
# (79,)
# (79,)
# (79,)
# (90,)
# (91,)
# (91,)
# (110,)
# (110,)
# (111,)
# (115,)
# (133,)
# (137,)
# (137,)
# (137,)
# (137,)
# (137,)
# (167,)
# (167,)
# (177,)
# (177,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (202,)
# (202,)
# (202,)
# (202,)
# (202,)
# (202,)
# (205,)
# (205,)
# (205,)
# (205,)
# (205,)
# (205,)
# (207,)
# (207,)
# (207,)
# (207,)
# (207,)
# (207,)
# (210,)
# (210,)
# (210,)
# (210,)
# (210,)
# (210,)
# (210,)
# (215,)
# (215,)
# (215,)
# (215,)
# (215,)
# (215,)
# (217,)
# (217,)
# (217,)
# (217,)
# (217,)
# (217,)
# (219,)
# (219,)
# (219,)
# (219,)
# (219,)
# (219,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# (279,)
# ...
